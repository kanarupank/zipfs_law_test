# %%
import re

file_name="tamil.txt"

file = open(file_name, "rt", encoding="utf8")
data = file.read()
words = data.split()
print('Number of words in text file :', len(words))
# Out:
# Number of words in text file : 249177

# %%
# Declare a dictionary 
dictionary = {} 
   
def hasNumbers(inputString):
    return bool(re.search(r'\d', inputString))

def isSpecialChar(char):
    special_punctuation_chars = "!\"#$%&'()*+, -./:;<=>?@[\\]^_`{|}~" #add all the punctuation, special marks.
    return char in special_punctuation_chars

# count method to store frequency of each word   
def count(word): 
        
    if not(hasNumbers(word) or isSpecialChar(word) or ''==word or None==word):
           
        # check if each word has special char at its last and ignore
        if isSpecialChar(word[-1]): 
            word = word[0:len(word) - 1] 

        # check if each word has special char at the beggning and ignore
        if isSpecialChar(word[0]): 
            word = word[1:len(word)-1] 
            
        # increment key if exists. 
        if word in dictionary: 
            dictionary[word] += 1

        # add new key "word" and set 1 as value. 
        else: 
            dictionary.update({word: 1}) 
        return 1
    else:
         #print('Not a word, skipped: '+ word)
        return 0

# %%
# take each word from words list (populated from the text file) and pass it to the count method. 
wordsAfterFiltering=0
for word in words: 
    if(count(word)>0):
        wordsAfterFiltering+=1
print("Words after filtering: "+str(wordsAfterFiltering))
   
# print the keys and its corresponding values. 
#for key in dictionary: 
 #   print ("Frequency of " + key + " : " + str(dictionary[key]) ) 
    
print('Number of unique, valid words: '+ str(len(dictionary.items())))
# Out:
# Words after filtering: 197752
# Number of unique, valid words: 33791

# %%
#sort dictionary in reverse order
sorted_tuples=sorted(dictionary.items(), reverse=True, key = 
             lambda kv:(kv[1], kv[0]))   

print(sorted_tuples)
# Out:
# [('மற்றும்', 2849), ('ஆம்', 2195), ('வேண்டும்', 1446), ('அல்லது', 1444), ('அவர்', 1131), ('திகதி', 1054), ('உத்தியோகத்தர்', 1018), ('கீழ்', 936), ('செயலாளர்', 834), ('தொடர்பாக', 733), ('மேற்படி', 651), ('மூலம்', 651), ('இலக்கம்', 651), ('பெற்றுக்', 608), ('ஒரு', 591), ('கெளரவ', 556), ('கல்வி', 550), ('பிரதேச', 492), ('இந்த', 480), ('அரச', 480), ('இலக்க', 479), ('உரிய', 467), ('தேசிய', 466), ('அபிவிருத்தி', 464), ('பணிப்பாளர்', 461), ('இலங்கை', 438), ('அரசாங்க', 426), ('நிதி', 411), ('யாது', 400), ('சேவை', 388), ('போது', 382), ('யாவை', 371), ('நடவடிக்கை', 366), ('திகதிய', 363), ('எண்ணிக்கை', 359), ('சட்டத்தின்', 358), ('பிரிவின்', 353), ('குறித்த', 349), ('கேட்பதற்கு', 346), ('விசேட', 345), ('முடியும்', 338), ('அமைச்சின்', 332), ('தேவையான', 326), ('எம்', 326), ('ஒருவர்', 321), ('அமைச்சரைக்', 316), ('அறிவிப்பாரா', 314), ('மாதம்', 303), ('எவ்வளவு', 301), ('தொடர்பான', 299), ('கடன்', 296), ('திரு', 294), ('சம்பள', 292), ('மாவட்ட', 286), ('பற்றிய', 286), ('முதல்', 283), ('ஆந்', 283), ('உங்கள்', 282), ('ஏனைய', 276), ('மாகாண', 273), ('அந்த', 271), ('வேண்டிய', 270), ('விடயம்', 270), ('என்பதை', 268), ('பாடசாலை', 260), ('ப', 259), ('செய்யப்பட்ட', 259), ('சபை', 257), ('ஆண்டின்', 257), ('வரை', 256), ('சகல', 254), ('அத்தகைய', 250), ('ரூபா', 249), ('கொண்ட', 248), ('சட்டமூலம்', 247), ('எனது', 245), ('அமைச்சு', 245), ('தயவுடன்', 242), ('இத்துடன்', 240), ('என்பதையும்', 238), ('பிரிவு', 237), ('குறிப்பிடுவாரா', 236), ('புதிய', 231), ('அதன்', 230), ('முன்னர்', 229), ('செய்து', 229), ('செய்தல்', 228), ('உதவி', 228), ('இச்சபைக்கு', 225), ('பொது', 222), ('கடிதம்', 221), ('அனைத்து', 218), ('தனது', 217), ('பி', 214), ('உள்ள', 211), ('ஆண்டு', 210), ('சமூக', 208), ('அறிக்கை', 208), ('மேலதிக', 206), ('திணைக்களத்', 205), ('எஸ்', 205), ('அது', 204), ('கிராம', 203), ('ஏ', 203), ('பின்னர்', 200), ('தயவாய்', 197), ('ஒருவருக்கு', 196), ('பதவி', 195), ('பயிற்சி', 193), ('பீ', 192), ('பிரதி', 190), ('சம்பளம்', 190), ('மத்திய', 188), ('பெயர்', 186), ('நடவடிக்கைகள்', 186), ('சேவைகள்', 183), ('கொடுப்பனவு', 180), ('கட்டளை', 180), ('அவ்வாறு', 179), ('மேலும்', 178), ('முன்', 178), ('கே', 178), ('அ', 178), ('நிகழ்ச்சி', 177), ('வேறு', 176), ('லீவு', 175), ('மேற்குறித்த', 175), ('வருடாந்த', 174), ('கொண்டு', 172), ('திணைக்களம்', 171), ('படி', 170), ('தலைவர்', 169), ('இல', 167), ('மொழி', 164), ('கூடிய', 164), ('அவரது', 162), ('கொள்ளல்', 161), ('தகவல்', 160), ('காரணமாக', 159), ('இரண்டாம்', 159), ('ஊடாக', 158), ('அதிகாரி', 158), ('கல்விப்', 157), ('அவருக்கு', 157), ('மதிப்பீடு', 156), ('ஒவ்வொரு', 156), ('அங்கீகரிக்கப்படுமாக', 156), ('பாதுகாப்பு', 154), ('தொகை', 154), ('வழங்க', 153), ('என்ற', 152), ('வெளிநாட்டு', 151), ('பொ', 150), ('பற்றி', 150), ('அமைச்சர்', 150), ('கொள்ள', 149), ('காலம்', 149), ('அதற்கமைய', 149), ('விடுமுறை', 148), ('மொழிகள்', 148), ('இது', 148), ('அதிவிசேட', 147), ('பெற்ற', 146), ('அடிப்படையில்', 146), ('தற்போது', 145), ('திருமதி', 144), ('மாத்தளை', 143), ('த', 143), ('சமர்ப்பிக்கப்பட்டதுமான', 142), ('இரண்டு', 142), ('ஆர்', 142), ('“', 141), ('ஆண்டில்', 141), ('குறிப்பிடப்பட்டுள்ள', 139), ('தெரிவு', 137), ('சனநாயக', 137), ('உத்தியோகத்தரின்', 137), ('ஆணையாளர்', 136), ('வகையில்', 135), ('தொகை', 135), ('மீண்டும்', 134), ('நாயகம்', 134), ('செலவு', 134), ('நிறுவனம்', 133), ('அதற்கு', 133), ('சோசலிசக்', 132), ('அரசியலமைப்பின்', 132), ('பின்வரும்', 131), ('செய்யும்', 131), ('இலங்கைச்', 131), ('ஆகிய', 131), ('KDS', 130), ('விளையாட்டு', 129), ('வழங்குதல்', 129), ('ஏற்ப', 129), ('என', 129), ('முகாமைத்துவ', 128), ('தமிழ்', 128), ('சார்பாக', 128), ('எச்', 128), ('ஒவ்வொரு', 126), ('அமைய', 126), ('செய்ய', 125), ('அனுமதி', 125), ('வேண்டியது', 124), ('திணைக்களத்தின்', 123), ('சேவையில்', 123), ('சிறுவர்', 123), ('ஏற்பாடுகள்', 123), ('திகதிக்கு', 122), ('”', 121), ('பதிவு', 121), ('காரியாலயம்', 121), ('தொழில்', 119), ('ஊழியர்', 119), ('வழங்கப்பட்ட', 118), ('புகையிரத', 118), ('திட்டமிடல்', 118), ('ரூ', 117), ('ஒன்று', 117), ('அலுவல்கள்', 117), ('ஆக்கப்பட்டு', 116), ('அரசாங்கம்', 116), ('நீங்கள்', 115), ('ஓர்', 115), ('வழங்கப்படும்', 114), ('சுகாதார', 113), ('எனக்கு', 1 ...

# %%
count=0
rank_list=[]
frequency_list=[]
for pair in sorted_tuples:
    count+=1
    rank_list.append(count)
    frequency_list.append(pair[1])

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

#plot the Gaussian curve
ax.plot(rank_list, frequency_list, label = "Rank vs Frequency")

ax.set(xlabel='Rank', ylabel='Frequency',
       title='Tamil.txt - Rank vs Frequecy Plot')
ax.grid()
plt.legend()
plt.show()

# %%
#frequency of frequencies
fof={}
for pair in sorted_tuples:
        # increment key if exists. 
        if pair[1] in fof: 
            fof[pair[1]] += 1

        # add new key "the frequency" and set 1 as value. 
        else: 
            fof.update({pair[1]: 1}) 

#sort dictionary in reverse order
sorted_fof=sorted(fof.items(), reverse=True, key = 
             lambda kv:(kv[1], kv[0]))   

print(sorted_fof)
# Out:
# [(1, 19396), (2, 5221), (3, 2223), (4, 1329), (5, 901), (6, 625), (7, 466), (8, 370), (9, 275), (10, 246), (11, 233), (13, 158), (12, 150), (14, 143), (15, 103), (16, 100), (17, 89), (18, 84), (19, 82), (21, 74), (20, 72), (22, 59), (25, 55), (24, 53), (23, 48), (28, 45), (26, 42), (31, 38), (30, 37), (29, 35), (27, 33), (38, 30), (35, 29), (41, 26), (39, 24