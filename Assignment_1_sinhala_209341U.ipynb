# %%
import re

file_name="sinhala.txt"

file = open(file_name, "rt", encoding="utf8")
data = file.read()
words = data.split()
print('Number of words in text file :', len(words))
# Out:
# Number of words in text file : 291637

# %%
# Declare a dictionary 
dictionary = {} 

def hasNumbers(inputString):
    return bool(re.search(r'\d', inputString))

def isSpecialChar(char):
    special_punctuation_chars = "!\"#$%&'()*+, -./:;<=>?@[\\]^_`{|}~" #add all the punctuation, special marks.
    return char in special_punctuation_chars

# count method to store frequency of each word   
def count(word): 
        
    if not(hasNumbers(word) or isSpecialChar(word) or ''==word or None==word):
           
        # check if each word has special char at its last and ignore
        if isSpecialChar(word[-1]): 
            word = word[0:len(word) - 1] 

        # check if each word has special char at the beggning and ignore
        if isSpecialChar(word[0]): 
            word = word[1:len(word)-1] 
            
        # increment key if exists. 
        if word in dictionary: 
            dictionary[word] += 1

        # add new key "word" and set 1 as value. 
        else: 
            dictionary.update({word: 1}) 
        return 1
    else:
         #print('Not a word, skipped: '+ word)
        return 0

# %%
total=0
# take each word from words list (populated from the text file) and pass it to the count method. 
for word in words: 
    total+=count(word) 
   
# print the keys and its corresponding values. 
#for key in dictionary: 
 #   print ("Frequency of " + key + " : " + str(dictionary[key]) ) 

print('Total words: '+str(total))
print('Number of unique, valid words: '+ str(len(dictionary.items())))
# Out:
# Total words: 240959
# Number of unique, valid words: 16772

# %%
#sort dictionary in reverse order
sorted_tuples=sorted(dictionary.items(), reverse=True, key = 
             lambda kv:(kv[1], kv[0]))   

print(sorted_tuples)
# Out:
# [('සඳහා', 3030), ('හා', 3029), ('යුතු', 2031), ('හෝ', 2014), ('ය', 1889), ('කරන', 1844), ('ඇති', 1776), ('එම', 1755), ('කළ', 1591), ('සහ', 1588), ('කිරීම', 1495), ('කර', 1475), ('ලබා', 1437), ('මෙම', 1386), ('ඒ', 1384), ('ලද', 1277), ('කටයුතු', 1224), ('විසින්', 1163), ('ද', 1156), ('වන', 1135), ('දින', 1107), ('නම්', 1094), ('සඳහන්', 1017), ('අංක', 984), ('ලේකම්', 932), ('වැනි', 899), ('කවරේද', 891), ('වෙත', 885), ('යටතේ', 875), ('අධ්\u200dයාපන', 832), ('වැටුප්', 828), ('ඉදිරිපත්', 820), ('අනුව', 819), ('එතුමා', 813), ('මහතා', 809), ('මේ', 805), ('කරනු', 790), ('ගරු', 774), ('එක්', 764), ('වූ', 762), ('රාජ්\u200dය', 760), ('නිවාඩු', 740), ('කිරීමට', 721), ('අදාළ', 711), ('ඇත', 699), ('කොපමණද', 682), ('දී', 668), ('ලෙස', 655), ('ලංකා', 638), ('වශයෙන්', 619), ('ලබන', 616), ('අතර', 616), ('වෙන්', 612), ('හැකි', 577), ('ශ්\u200dරී', 575), ('බව', 575), ('සිට', 572), ('මුදල්', 566), ('සම්බන්ධයෙන්', 563), ('දරන', 557), ('සේවා', 550), ('කිරීමේ', 540), ('පළාත්', 523), ('සංවර්ධන', 521), ('පරිදි', 521), ('විශේෂ', 516), ('අවශ්\u200dය', 511), ('ජාතික', 507), ('අනුමත', 498), ('දිනය', 484), ('දිනැති', 473), ('භාෂා', 469), ('වෙනුවෙන්', 468), ('ගැනීම', 467), ('කාරුණිකව', 465), ('දක්වා', 464), ('තුළ', 461), ('ඉහත', 454), ('එසේ', 450), ('පිළිබඳ', 449), ('සේවය', 441), ('සංඛ්\u200dයාව', 440), ('විට', 432), ('මුදල', 428), ('රජයේ', 427), ('පහත', 416), ('ණය', 415), ('ක්\u200dරියාත්මක', 406), ('අධ්\u200dයක්ෂ', 406), ('ගත', 404), ('ඔබ', 396), ('නිලධරයෙකු', 394), ('මගින්', 384), ('සිදු', 382), ('පත්', 382), ('ප්\u200dරාදේශීය', 376), ('ගැනීමට', 374), ('කරන්නෙහිද', 369), ('යන', 367), ('වැඩසටහන්', 364), ('ඇසීමට', 364), ('අමාත්\u200dයතුමාගෙන්', 359), ('සභාවට', 354), ('වෙනත්', 354), ('ඔහු', 352), ('වේ', 351), ('ආයතන', 344), ('විය', 335), ('පෙර', 335), ('පාසල්', 335), ('තොරතුරු', 335), ('රු', 332), ('අංකය', 330), ('බවත්', 329), ('දන්වන්නෙහිද', 329), ('දිස්ත්\u200dරික්', 327), ('එම්', 323), ('දෙන', 322), ('වැඩසටහන', 320), ('කාලය', 318), ('සමග', 316), ('වගන්තිය', 314), ('අමාත්\u200dයාංශය', 313), ('සහකාර', 312), ('උක්ත', 306), ('කාල', 305), ('යුතුය', 299), ('වැඩ', 298), ('ලිපිය', 293), ('වාර්තා', 286), ('යන්න', 280), ('නිලධරයා', 276), ('වියදම්', 275), ('දන්වමි', 274), ('වී', 271), ('අ', 271), ('පනතේ', 268), ('විශ්\u200dරාම', 266), ('ගෙන', 264), ('ශ\u200d්\u200dරී', 262), ('දිය', 262), ('අවසන්', 262), ('නිලධරයෙකුට', 260), ('දෙපාර්තමේන්තු', 260), ('සේවයේ', 258), ('වැඩි', 258), ('සියලුම', 257), ('නිකුත්', 257), ('ඔහුට', 257), ('පනත්', 255), ('වාර්තාව', 253), ('නිවාස', 247), ('ගමන්', 246), ('ලැබූ', 243), ('සිටින', 236), ('දන්වා', 236), ('අය', 234), ('අමාත්\u200dයාංශයේ', 234), ('ඊට', 231), ('සිටිමි', 230), ('වෛද්\u200dය', 230), ('ඇතුළත්', 228), ('පිළිබඳව', 227), ('කාර්යාලය', 226), ('මත', 225), ('සම්පූර්ණ', 221), ('කොට', 220), ('මගේ', 219), ('ගන්නා', 218), ('එස්', 217), ('එකී', 217), ('ප්\u200dරධාන', 215), ('නිලධාරීන්', 215), ('දීම', 213), ('වර්ෂයේ', 212), ('බවට', 211), ('මස', 210), ('ආයතනය', 210), ('ව', 209), ('කෙටුම්පත', 208), ('ඔහුගේ', 208), ('ගෙවිය', 205), ('ආරම්භ', 205), ('ලැබ', 204), ('ස', 203), ('දෙපාර්තමේන්තුව', 203), ('එහි', 203), ('මා', 202), ('පරිපාලන', 200), ('තිබේද', 199), ('සමඟ', 198), ('යෝජනා', 198), ('ඔබගේ', 196), ('ඉල්ලා', 195), ('අයත්', 195), ('සමාජ', 194), ('නිසා', 194), ('මෙන්', 193), ('යොමු', 192), ('නිලධාරී', 190), ('ජනරාල්', 189), ('ගත්', 189), ('නියමිත', 188), ('කරමි', 188), ('නව', 187), ('සෑම', 186), ('පළ', 185), ('රාජකාරි', 184), ('කේ', 183), ('නියෝග', 182), ('ගැසට්', 182), ('අඩු', 182), ('ලැබේ', 181), ('යම්', 181), ('එය', 181), ('සකස්', 180), ('විදේශ', 180), ('ගාස්තු', 179), ('ග්\u200dරාම', 179), ('කාර්ය', 179), ('පහසුකම්', 178), ('තාක්ෂණ', 178), ('යුත්තේ', 177), ('ස්ථිර', 176), ('වර්ෂය', 176), ('ක්', 175), ('සභාව', 174), ('භාර', 173), ('සහිත', 172), ('වාර්ෂික', 172), ('දීමට', 172), ('සේවක', 171), ('බදු', 171), ('සලකා', 170), ('දිනට', 170), ('ලිපි', 169), ('බැඳේ', 168), ('පුහුණු', 168), ('අති', 168), ('පොදු', 166), ('සමාජවාදී', 164), ('විධිවිධාන', 164), ('දුම්රිය', 163), ('කරුණ', 163), ('වැටුප', 162), ('භාණ්ඩ', 162), ('ජනරජයේ', 162), ('ලදුව ...

# %%
count=0
rank_list=[]
frequency_list=[]
for pair in sorted_tuples:
    count+=1
    rank_list.append(count)
    frequency_list.append(pair[1])

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

#plot the Gaussian curve
ax.plot(log(rank_list), log(frequency_list), label = "Rank vs Frequency")

ax.set(xlabel='Rank', ylabel='Frequency',
       title='Sinhala.txt - Rank vs Frequecy Plot')
ax.grid()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-f42fdeb56e4a> in <module>
#       4
#       5 #plot the Gaussian curve
# ----> 6 ax.plot(log(rank_list), log(frequency_list), label = "Rank vs Frequency")
#       7
#       8 ax.set(xlabel='Rank', ylabel='Frequency',
#
# NameError: name 'log' is not defined

# %%
#frequency of frequencies
fof={}
for pair in sorted_tuples:
        # increment key if exists. 
        if pair[1] in fof: 
            fof[pair[1]] += 1

        # add new key "the frequency" and set 1 as value. 
        else: 
            fof.update({pair[1]: 1}) 

#sort dictionary in reverse order
sorted_fof=sorted(fof.items(), reverse=True, key = 
             lambda kv:(kv[1], kv[0]))   

print(sorted_fof)
# Out:
# [(1, 7316), (2, 2689), (3, 1301), (4, 855), (5, 548), (6, 435), (7, 349), (9, 234), (8, 216), (10, 189), (11, 168), (12, 149), (13, 121), (14, 118), (15, 112), (16, 74), (17, 72), (18, 67), (19, 63), (21, 55), (20, 50), (28, 46), (23, 46), (22, 46), (25, 44), (24, 38), (27, 37), (26, 36), (30, 33), (34, 30), (33, 30), (31, 29), (35, 27), (32, 27), (40, 26), (29, 26), (46, 25), (48, 24), (37, 23), (43, 22), (36, 21), (39, 20), (38, 20), (51, 17), (49, 17), (47, 17), (41, 17), (69, 16), (42, 16), (56, 15), (44, 15), (50, 14), (45, 13), (60, 12), (58, 12), (83, 11), (74, 11), (65, 11), (59, 11), (55, 11), (81, 10), (72, 10), (62, 10), (103, 9), (87, 9), (85, 9), (77, 9), (63, 9), (57, 9), (54, 9), (95, 8), (73, 8), (61, 8), (52, 8), (161, 7), (144, 7), (80, 7), (75, 7), (71, 7), (70, 7), (67, 7), (66, 7), (64, 7), (130, 6), (114, 6), (110, 6), (108, 6), (99, 6), (90, 6), (89, 6), (79, 6), (53, 6), (